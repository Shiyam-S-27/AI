# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiyam-S-27/AI/blob/main/Forward_chaining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Forward chaining

# %%
# Forward Chaining Example
# Known facts
facts = {"Human(Socrates)"}
# Rule: IF Human(Socrates) THEN Mortal(Socrates)
if "Human(Socrates)" in facts:
    facts.add("Mortal(Socrates)")
# Display all facts after inference
print("Facts after Forward Chaining:")
for fact in facts:
    print(fact)
# Out:
# Facts after Forward Chaining:
# Mortal(Socrates)
# Human(Socrates)

# %%
# Forward Chaining Example

# Initial fact
facts = {"Study"}

# Rule: If Study then Pass
if "Study" in facts:
    facts.add("Pass")

# Print inferred facts
print("Knowledge Base:")
for fact in facts:
    print(fact)
# Out:
# Knowledge Base:
# Study
# Pass
